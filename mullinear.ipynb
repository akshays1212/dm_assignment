# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv')
X = data[['sqr_foot', 'bedroom']]
y = data['price']

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
coefficients = model.coef_
intercept = model.intercept_

print("Coefficients:", coefficients)
print("Intercept:", intercept)
# Out:
# Coefficients: [ 156.48414986 7809.79827089]
# Intercept: 87406.34005763679

# %%
ts=pd.read_csv('test.csv')
new_data=ts[['sqr_foot','bedroom']]

# %%
pred = model.predict(new_data)
print("Predictions:", pred)
print(f"Coefficient for square footage: {coefficients[0]}")
print(f"Coefficient for number of bedrooms: {coefficients[1]}")
# Out:
# Predictions: [361210.37463977 462910.66282421 329913.54466859 470720.4610951 ]
# Coefficient for square footage: 156.48414985590784
# Coefficient for number of bedrooms: 7809.798270893368
